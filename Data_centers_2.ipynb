# %% [markdown]
# <a href="https://colab.research.google.com/github/giolanta-nta/Homework/blob/main/Data_centers_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/combined_data.csv")
df
# Out:
#     Continent          Regions            Code  Zones         City State  \
# 0        Asia           China       cn-qingdao      2      Qingdao   NaN
# 1        Asia           China       cn-beijing     12      Beijing   NaN
# 2        Asia           China   cn-zhangjiakou      3  Zhangjiakou   NaN
# 3        Asia           China     cn-huhehaote      2       Hohhot   NaN
# 4        Asia           China    cn-wulanchabu      3      Ulanqab   NaN
# ..        ...              ...             ...    ...          ...   ...
# 225      Asia        UAE East       me-dubai-1      1        Dubai   NaN
# 226      Asia     UAE Central    me-abudhabi-1      1    Abu Dhabi   NaN
# 227      Asia        Israel 2              TBD      1     Tel Aviv   NaN
# 228      Asia  Saudi Arabia 2              TBD      1       Riyadh   NaN
# 229      Asia  Saudi Arabia 3              TBD      1         Neom   NaN
#
#           Country  Opened  Latitude  Longitude  Company              Location
# ...

# %%
df.dtypes
# Out:
# Continent     object
# Regions       object
# Code          object
# Zones          int64
# City          object
# State         object
# Country       object
# Opened        object
# Latitude     float64
# Longitude    float64
# Company       object
# Location      object
# dtype: object

# %%
df.shape
# Out:
# (230, 12)

# %%
df.sort_values(by="Latitude")
# Out:
#     Continent               Regions                  Code  Zones       City  \
# 52    Oceania         Asia Pacific         ap-southeast-4      3  Melbourne
# 105   Oceania             Melbourne  australia-southeast2      3  Melbourne
# 212   Oceania  Australia Southeast         ap-melbourne-1      1  Melbourne
# 106   Oceania           New Zealand                   TBD      3   Auckland
# 46    Oceania         Asia Pacific         ap-southeast-5      3   Auckland
# ..        ...                   ...                   ...    ...        ...
# 168    Europe           Norway East            norwayeast      3       Oslo
# 157    Europe       Finland Central        finlandcentral      1   Helsinki
# 80     Europe               Finland         europe-north1      3     Hamina
# 173    Europe        Sweden Central         swedencentral      3      Gavle
# 116    Europe                   NaN                   NaN      1      Lulea
#
# ...

# %%
df.value_counts()
# Out:
# Continent      Regions              Code                     Zones  City            State           Country        Opened  Latitude  Longitude  Company    Location
# North America  AWS GovCloud         us-gov-east-1            3      Columbus        Ohio            United States  2018     32.5100  -84.8771   amazon     Columbus, Ohio, United States                   1
#                Canada               ca-central-1             3      Montreal        Quebec          Canada         2016     45.5089  -73.5617   amazon     Montreal, Quebec, Canada                        1
#                                     ca-west-1                3      Calgary         Alberta         Canada         2024     51.0500  -114.0667  amazon     Calgary, Alberta, Canada                        1
#                Canada Central       canadacentral            3      Toronto         Ontario         Canada         2016     43.7417  -79.3733   microsoft  Toronto, Ontario, Canada                        1
# ...
