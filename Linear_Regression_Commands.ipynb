# %% [markdown]
# <a href="https://colab.research.google.com/github/giolanta-nta/Homework/blob/main/Linear_Regression_Commands.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Εντολές για Liner Regression models

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns

# special matplotlib argument for improved plots
from matplotlib import rcParams
sns.set_style("whitegrid")
sns.set_context("poster")

# %%
from sklearn.datasets import df_name

# %%
df = pd.read_csv ("...")

# %%
Εντολές describe, dtypes, shape, head, etc

# %%
df.isnull().sum()

# %%
# ορίζουμε τις τιμές που λείπουν
missing_values = ["n/a", "na", "--", 999,9999]
# τις αλλάζουμε όνομα
df.replace(to_replace = missing_values, value = np.nan, inplace = True)
# πετάμε τις γραμμές με NaNs
df.dropna(inplace=True)
# Ξαναφέρνουμε το index στη σωστή σειρά, πάντα μετά από κόψιμο και πέταμα στηλών χρειάζεται reindex
df.reset_index(drop=True, inplace=True)

# %%
# Αν πρέπει να πετάξουμε τις γραμμές 11 και 14, τότε....
#ls_lines_to_drop = [11,14]
#df.drop(ls_lines_to_drop, inplace=True)
#df.head(20)

# %%
df.rename(columns={"hr": "hour", "dteday":"date", }, inplace=True)
df  = df.drop(["...", "..."],axis=1)

# %%
X = df[['...' '...']]
y = df['...']

# %%
# Βάζουμε τα data σε DataFrame
housing_df = pd.DataFrame(housing.data, columns=housing.feature_names)
# προσθέτουμε το target στο DataFrame
housing_df['PRICE'] = pd.DataFrame(housing.target)

# %%
#split
california_train, california_test = train_test_split(housing_df, random_state=42)

# Βάζουμε όλα τα features στο X_train και βγάζουμε το PRICE γιατί είναι το target
X_train = california_train.drop(columns='PRICE')
# Το target 'price' στο y_train
y_train = california_train['PRICE']

# Βάζουμε όλα τα features στο X_train και βγάζουμε το PRICE γιατί είναι το target
X_test = california_test.drop(columns = 'PRICE')
# Το target 'price' στο y_train
y_test = california_test['PRICE']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)
# Εισαγωγή μοντέλου
lm=LinearRegression()
# Εκπαίδευση
lm.fit(x_train,y_train)
# Πρόβλεψη
y_pred = lm.predict(x_test)
# Υπολογισμός λάθους
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = round(r2_score(y_test, y_pred), 2)
# Coefficients
b = lm.coef_
# Intercept
d = lm.intercept_
# Γράφουμε σε κείμενο τα λάθη
txt = "R2 = {} \nRMSE = {} \ncoef = {} \nintercept = {}"
# και τα τυπώνουμε
print(txt.format(r2, rmse, b, d))

# %%
#Σημασία εντολών
lm.fit()	Fit a linear model
lm.predict()	Predict Y using the linear model with estimated coefficients
lm.score()	Returns the coefficient of determination (R^2). A measure of how well observed outcomes are replicated by the model, as the proportion of total variation of outcomes explained by the model

# %%
#Scatter plots
plt.scatter(df.column_1, df.column_2, s = 2)
plt.xlabel("...")
plt.ylabel("...")
plt.title("...")

# %%
plt.plot(x_test.column_1, y_pred, color='red') # οπτικοποιεί την πρόβλεψη
plt.savefig('lin_reg_df.png', dpi=150, bbox_inches='tight') # Σώζει την εικόνα
plt.show()

# %%
plt.xticks(np.arange(0, 10, step=1))
plt.yticks(np.arange(0, 10, step=1))
#ticks=διαβαθμίσεις στο γράφημα

plt.plot(np.arange(0, 10, step=1), np.arange(0, 10, step=1), color = 'red')
plt.show()
plt.clf()

# %% [markdown]
# **Decision Tree Commands**

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
#regr_tree = DecisionTreeRegressor(max_depth=8)
regr_tree = DecisionTreeRegressor(min_samples_leaf = 8)

# %%
# Fit το decision tree model
regr_tree.fit(x_train, y_train)

# %%
# predictions
y_pred = regr_tree.predict(x_test)
# Print predictions
print(y_pred)

# %%
# λάθος MSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
# λάθος R squared
r2 = round(r2_score(y_test, y_pred),2)

txt_one_feature = "R2 = {} \nRMSE = {}"


print(txt_one_feature.format(r2, rmse))

# %%
# Οπτικοποίηση αποτελεσμάτων
plt.figure()
plt.scatter(x_test['AveRooms'], y_test, s=20, edgecolor="darkorange",
            c="r", label="data")
plt.scatter(x_test['AveRooms'], y_pred, color="b", label="max_depth=2", linewidth=2)
plt.xlabel("Number of rooms")
plt.ylabel("Price")
plt.title("Decision Tree on California housing")
plt.legend()
#final plot
plt.show()

# %%
from sklearn.tree import plot_tree

# %%
#tree plot
plot_tree(regr_tree, fontsize=3)
plt.figure(figsize=(100,100))

plt.show()

# %% [markdown]
# Δοκιμάστε διαφορετικό βάθος δέντρων για να βρείτε διαφορές. Γενικά παρατηρούμε ότι με το decision tree παίρνουμε κοντινά αποτελέσματα όπως και στο γραμμικό μοντέλο αλλά εξηγεί μεγαλύτερο variance σε σχέση με το γραμμικό μοντέλο.

# %%
regr_1 = DecisionTreeRegressor(max_depth=5)
regr_2 = DecisionTreeRegressor(max_depth=20) #overfit
# Fit τα tree regression models
regr_1.fit(x, y)
regr_2.fit(x, y)
# προβλέψεις
y_1 = regr_1.predict(x_test)
y_2 = regr_2.predict(x_test)

# %%
# visualizing our decision tree
import graphviz
from sklearn.tree import export_graphviz

dot_data = export_graphviz(regr_tree)
graphviz.Source(export_graphviz(regr_tree,
                                out_file=None,
                                feature_names=X_train.columns,
                                class_names=["0", "1"],
                                node_ids = True,
                                impurity=True))

# %%
#tree plot
plot_tree(regr_tree)

plt.show()
