# %% [markdown]
# <a href="https://colab.research.google.com/github/giolanta-nta/Homework/blob/main/HW_3_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Έχουμε ένα αρχείο .csv το οποίο περιέχει τις καλύτερες 1000 ταινίες του IMDB και θα χρησιμοποιήσουμε αυτά τα δεδομένα για να οπτικοποιήσουμε και να πραγματοποιήσουμε κάποιες αναλύσεις σε αυτά χρησιμοποιώντας την Python και τη βιβλιοθήκη των Pandas που μάθαμε πρόσφατα.
# Θα χρησιμοποιήσουμε τη μορφή Jupyter Notebook που μας παρέχει το περιβάλλον Collab της Google, για να φτιάξουμε τον κώδικά μας. Το πρώτο πράγμα είναι κάνουμε εισαγωγή (import) τις βιβλιοθήκες μας Pandas και Matplot. Pandas για τα dataframes και την ανάλυσή μας και τη Matplot για την οπτικοποίησή μας.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
movies  = pd.read_csv("https://raw.githubusercontent.com/thechaudharysab/imdb-data-pandas-visualization/master/data/imdb_1000.csv")

# %%
df = pd.DataFrame(movies)

# %% [markdown]
# βλέπουμε τις 5 πρώτες γραμμές των δεδομένων μας

# %%
df.head (5)
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# Ελέγχουμε τις γραμμές και τις στήλες του πίνακά μας (του dataframe ορθότερα)

# %%
df.shape
# Out:
# (979, 6)

# %% [markdown]
# Ελέγχουμε τον τύπο δεδομένων της κάθε στήλης

# %%
df.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# υπολογίζουμε τη μέση διάρκεια όλων των ταινιών

# %%
df['duration'].mean()
# Out:
# np.float64(120.97957099080695)

# %% [markdown]
# ταξινομούμε το DataFrame ως προς τη διάρκεια για να βρούμε τη μικρότερη και τη μεγαλύτερη σε διάρκεια ταινία

# %%
df.sort_values(by='duration')
# Out:
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 88           8.4                            The Kid      NOT RATED     Comedy
# 293          8.1                          Duck Soup         PASSED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
# ...

# %% [markdown]
# Η πιο μικρή σε διάρκεια ταινία

# %%
df['duration'].min()
# Out:
# 64

# %%
df.sort_values(by='duration', ascending=True).head(1)
# Out:
#      star_rating   title content_rating  genre  duration  \
# 389          8.0  Freaks        UNRATED  Drama        64
#
#                                            actors_list
# 389  [u'Wallace Ford', u'Leila Hyams', u'Olga Bacla...

# %% [markdown]
# Η πιο μεγάλη σε διάρκεια ταινία

# %%
df['duration'].max()
# Out:
# 242

# %%
df.sort_values(by='duration', ascending=True).tail(1)
# Out:
#      star_rating   title content_rating  genre  duration  \
# 476          7.8  Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %% [markdown]
# δημιουργούμε ένα ιστόγραμμα με τις συχνότητες των ταινιών σε διάρκεια, επιλέγοντας έναν “κατάλληλο” αριθμό bins (ομάδων)

# %%
# %matplotlib inline
df['duration'].plot(kind='hist', bins=10, xlabel='duration')
# Out:
# <Axes: xlabel='duration', ylabel='Frequency'>

# %% [markdown]
# χρησιμοποίησε ένα box διάγραμμα για την παρουσίαση των ίδιων δεδομένων

# %%
df['duration'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Ας μετρήσουμε πόσες ταινίες έχουν καθεμία από τις βαθμολογίες περιεχομένου (content ratings)

# %%
df['content_rating'].value_counts()
# Out:
# content_rating
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: count, dtype: int64

# %% [markdown]
# Ας χρησιμοποιήσουμε ένα διάγραμμα τύπου στήλης (bar diagram) για να παρουσιάσουμε τα αποτελέσματα, συμπεριλαμβανομένων  και των τίτλων του άξονα x και y...

# %%
df.plot(kind='bar', xlabel='value-counts', ylabel='content_rating')
# Out:
# <Axes: xlabel='value-counts', ylabel='content_rating'>

# %% [markdown]
# μετατράπουμε τις βαθμολογίες τύπου  X και  TV-MA σε “NC-17”:

# %%
df['content_rating']=df['content_rating'].replace (['X', 'TV-MA'], 'NC-17')

# %%
df['content_rating'].value_counts()
# Out:
# content_rating
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# NC-17         12
# PASSED         7
# GP             3
# Name: count, dtype: int64

# %% [markdown]
# Ας μετρήσουμε τις τιμές που λείπουν σε κάθε στήλη
# Αν υπαρχουν ας τις εξετάσουμε και ας τις συμπληρώσουμε με μια κατάλληλη τιμή

# %%
df.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
df.content_rating.isnull().sum()
# Out:
# np.int64(3)

# %%
df[df['content_rating'].isnull()]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
import numpy as pd

# %%
df['content_rating'] = df['content_rating'].replace({'NOT RATED': 'GP', 'UNRATED': 'GP', np.nan: 'GP'})

# %%
df['content_rating'].value_counts()
# Out:
# content_rating
# R           465
# PG-13       190
# PG          123
# GP          103
# APPROVED     47
# G            32
# NC-17        12
# PASSED        7
# Name: count, dtype: int64

# %%
df[df['content_rating'].isnull()]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %% [markdown]
# υπολογίστε τη μέση βαθμολογία  (star rating) για ταινίες με διάρκεια μεγαλύτερη από 2 ώρες και συγκρίνετέ τη με τη μέση βαθμολογία των ταινιών με μικρότερη διάρκεια.

# %%
df[df['duration']>120]['star_rating'].mean()
# Out:
# np.float64(7.953669724770642)

# %%
df[df['duration']<120]['star_rating'].mean()
# Out:
# np.float64(7.838666666666665)

# %%
df[df['duration']>120]['star_rating'].mean()==df[df['duration']<120]['star_rating'].mean()
# Out:
# np.False_

# %% [markdown]
# ας φτιάξουμε ένα γράφημα για να δούμε αν υπάρχει συσχέτιση μεταξύ της διάρκειας μιας ταινίας και της βαθμολογίας της.

# %%
df.plot(kind='bar', xlabel='duration', ylabel='star_rating')
# Out:
# <Axes: xlabel='duration', ylabel='star_rating'>

# %% [markdown]
# Ας υπολογίσουμε τη μέση διάρκεια σε κάθε κατηγορία (και γραφικά)

# %%
df['duration'].mean()
# Out:
# np.float64(120.97957099080695)

# %%
df.groupby('genre')['duration'].mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %%
df.groupby('genre')['duration'].mean().sort_values(ascending=True)
# Out:
# genre
# History       66.000000
# Animation     96.596774
# Film-Noir     97.333333
# Horror       102.517241
# Family       107.500000
# Comedy       107.602564
# Sci-Fi       109.000000
# Fantasy      112.000000
# Thriller     114.200000
# Mystery      115.625000
# Crime        122.298387
# Action       126.485294
# Drama        126.539568
# Biography    131.844156
# Adventure    134.840000
# Western      136.666667
# Name: duration, dtype: float64

# %%
df.groupby('genre')['duration'].plot(kind='hist', bins=10, xlabel='duration')
plt.axvline(df['duration'].mean(), color='red')

# %% [markdown]
# βλέπουμε τη σχέση μεταξύ βαθμολογίας και content rating

# %%
df.groupby('content_rating')['star_rating'].mean()
# Out:
# content_rating
# APPROVED     8.027660
# G            7.990625
# GP           7.933333
# NC-17        7.758333
# NOT RATED    8.123077
# PASSED       8.157143
# PG           7.879675
# PG-13        7.828571
# R            7.854783
# UNRATED      7.994737
# Name: star_rating, dtype: float64

# %%
df.groupby('content_rating')['star_rating'].mean().sort_values(ascending=False)
# Out:
# content_rating
# PASSED      8.157143
# GP          8.071698
# APPROVED    8.027660
# G           7.990625
# PG          7.879675
# R           7.854783
# PG-13       7.828571
# NC-17       7.758333
# Name: star_rating, dtype: float64

# %%
df.groupby('content_rating')['star_rating'].mean().plot(kind='bar', xlabel='content_rating', ylabel='star_rating')
# Out:
# <Axes: xlabel='content_rating', ylabel='star_rating'>

# %% [markdown]
# Ας βρούμε τις καλύτερες ταινίες (by star rating) για κάθε κατηγορία

# %%
df.sort_values(by='star_rating', ascending=False)
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 958          7.4                               My Sister's Keeper
# 959          7.4                             Deconstructing Harry
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
df.sort_values(by=['genre','star_rating'], ascending=False)
# Out:
#      star_rating                                            title  \
# 6            8.9                   The Good, the Bad and the Ugly
# 26           8.6                     Once Upon a Time in the West
# 59           8.5                                 Django Unchained
# 107          8.3                           For a Few Dollars More
# 119          8.3                                       Unforgiven
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating    genre  duration  \
# 6        NOT RATED  Western       161
# 26           PG-13  Western       175
# 59               R  Western       165
# ...

# %%
df.sort_values(by='star_rating', ascending=False).groupby('genre').head(1)
# Out:
#      star_rating                                          title  \
# 0            9.3                       The Shawshank Redemption
# 3            9.0                                The Dark Knight
# 9            8.9                                     Fight Club
# 8            8.9                               Schindler's List
# 6            8.9                 The Good, the Bad and the Ugly
# 7            8.9  The Lord of the Rings: The Return of the King
# 38           8.6                                    Rear Window
# 39           8.6                                         Psycho
# 35           8.6                                   Modern Times
# 30           8.6                                  Spirited Away
# 105          8.3                                  The Third Man
# 145          8.2                                   Blade Runner
# 338          8.0                            Battleship Potemkin
# 350          8.0                              Shadow of a Doubt
# ...

# %% [markdown]
# Ας υπολογίσουμε τη μέση βαθμολογία για κάθε κατηγορία

# %%
df.groupby('genre')['star_rating'].mean()
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Family       7.850000
# Fantasy      7.700000
# Film-Noir    8.033333
# History      8.000000
# Horror       7.806897
# Mystery      7.975000
# Sci-Fi       7.920000
# Thriller     7.680000
# Western      8.255556
# Name: star_rating, dtype: float64

# %%
df.groupby('genre')['star_rating'].mean().sort_values(ascending=True)
# Out:
# genre
# Thriller     7.680000
# Fantasy      7.700000
# Horror       7.806897
# Comedy       7.822436
# Family       7.850000
# Biography    7.862338
# Action       7.884559
# Drama        7.902518
# Animation    7.914516
# Crime        7.916935
# Sci-Fi       7.920000
# Adventure    7.933333
# Mystery      7.975000
# History      8.000000
# Film-Noir    8.033333
# Western      8.255556
# Name: star_rating, dtype: float64
