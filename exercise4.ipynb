# %% [markdown]
# <a href="https://colab.research.google.com/github/giolanta-nta/Homework/blob/main/exercise4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Άσκηση 1
#
# Γράψτε ένα προγραμματάκι που θα αθροίζει όλους τους περιττούς αριθμούς από το 1 έως και το 100 και θα τυπώνει το τελικό άθροισμα.
#
# Hints & tips:
#
# - περιττοί είναι οι αριθμοί που το υπόλοιπο της διαίρεσής τους με το 2 ΔΕΝ είναι 0 (x % 2 != 0)
# - μπορούμε αρχικά να ορίσουμε ότι το άθροισμα των περιττών αριθμών είναι 0 (sum = 0)
# - στη συνέχεια μπορούμε να φτιάξουμε μια λούπα που θα κάνει τα εξής:
#   - για κάθε αριθμό από το 1 ως και το 100
#   - αν το υπόλοιπο της διαίρεσης του αριθμού με το 2 δεν είναι 0
#   - το άθροισμα θα αυξάνεται κατά τον αριθμό

# %%
sum = 0

# %%
for i in range(0,100):
  if i % 2 != 0:
    sum = sum + i

# %%
print(sum)
# Out:
# 2500

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 2
#
# Τροποποιήστε το παραπάνω πρόγραμμα έτσι ώστε, εκτός από το άθροισμα των περιττών, να υπολογίζει και να τυπώνει ΚΑΙ:
# - το πλήθος των περιττών αριθμών
# - το άθροισμα των ζυγών αριθμών στο ίδιο εύρος
# - το πλήθος των ζυγών αριθμών

# %%
odd_count = 0

# %%
for i in range(0,100):
  if i % 2 != 0:
    odd_count = odd_count + 1

# %%
print(odd_count)
# Out:
# 50

# %%
sum = 0
for i in range(0,100):
  if i % 2 == 0:
    sum = sum + i

# %%
print(sum)
# Out:
# 2450

# %%
odd_count = 0
for i in range(0,100):
  if i % 2 == 0:
    odd_count = odd_count + 1

# %%
print(odd_count)
# Out:
# 50

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 3
#
# Αντιγράψτε εδώ τον κώδικα που γράψατε για την 1η Άσκηση του notebook "exercise3.ipynb".
#
# Θα χρειαστούμε τη λίστα με τα λεξικά των άρθρων.
#
# Χρησιμοποιώντας τη βιβλιοθήκη Pandas, φτιάξτε ένα dataframe με τα δεδομένα της λίστας με τα λεξικά των άρθρων.
# Στη συνέχεια, εμφανίστε το dataframe στην οθόνη.
#
# **Hints & tips**:
# - για να χρησιμοποιήσετε τη βιβλιοθήκη pandas πρέπει πρώτα να την εισάγετε: import pandas as pd
# - η δημιουργία ενός dataframe από μια λίστα με λεξικά, γίνεται με την εξής σύνταξη: df = pd.DataFrame(<όνομα λίστας με λεξικά>)

# %%
L = []

# %%
article_1 = {
    'title': "Από τα στενά του Ορμούζ στη Χαλάστρα: Πώς ο πόλεμος φουσκώνει τα λιπάσματα",
    'date': "22-03-2026",
    'category': "Reportage",
    'url': "https://www.news247.gr/magazine/reportage/apo-ta-stena-tou-ormouz-sti-xalastra-pos-o-polemos-fouskonei-ta-lipasmata/",
    'site': "News247"
}

# %%
article_2 = {
    'title': "Βρετανία: Η βάση στην Κύπρο δεν θα χρησιμοποιηθεί για επιχειρήσεις στο Ιράν",
    'date': "21-03-2026",
    'category': "Εξωτερική Πολιτική",
    'url': "https://www.kathimerini.gr/politics/foreign-policy/564138802/vretania-i-vasi-stin-kypro-den-tha-chrisimopoiithei-gia-epicheiriseis-sto-iran/",
    'site': "Kathimerini"
}

# %%
L = [article_1, article_2]

# %%
import pandas as pd

# %%
df = pd.DataFrame (L)
display(df)
# Out:
#                                                title        date  \
# 0  Από τα στενά του Ορμούζ στη Χαλάστρα: Πώς ο πό...  22-03-2026
# 1  Βρετανία: Η βάση στην Κύπρο δεν θα χρησιμοποιη...  21-03-2026
#
#              category                                                url  \
# 0           Reportage  https://www.news247.gr/magazine/reportage/apo-...
# 1  Εξωτερική Πολιτική  https://www.kathimerini.gr/politics/foreign-po...
#
#           site
# 0      News247
# 1  Kathimerini

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 4 (intro)
#
# Στο site "ourworldindata.org" παρέχονται πάρα πολλά δεδομένα και γραφήματα για διάφορα topics για όλες τις χώρες του κόσμου.
#
# Για παράδειγμα, στη σελίδα https://ourworldindata.org/explorers/covid?Metric=Excess+mortality+%28estimates%29&Interval=Cumulative&Relative+to+population=false&country=USA~BRA~JPN~DEU, παρέχονται δεδομένα και γραφήματα σχετικά με την Covid-19.
#
# Αν επισκεφθείτε την παραπάνω σελίδα, επάνω αριστερά, υπάρχει ένας υπερσύνδεσμος με το κείμενο "Download this dataset". Εάν τον πατήσετε θα οδηγηθείτε στη σελίδα με τα datasets για τον covid.
#
# Πιο κάτω, σ' αυτή τη σελίδα, υπάρχει η ενότητα "Download data", με πολλά κουμπάκια download.
#
# Όταν πατήσετε κάποιο download μεταφέρεστε στη σελίδα του raw αρχείου csv με τα δεδομένα.
#
# Μπορούμε να φέρουμε αυτά τα δεδομένα σε ένα dataframe στην Python, με την παρακάτω εντολή:

# %%
covid_df = pd.read_csv("https://catalog.ourworldindata.org/garden/covid/latest/cases_deaths/cases_deaths.csv")
covid_df
# Out:
#             country        date  new_cases  total_cases  new_deaths  \
# 0       Afghanistan  2020-01-04        0.0            0         0.0
# 1       Afghanistan  2020-01-05        0.0            0         0.0
# 2       Afghanistan  2020-01-06        0.0            0         0.0
# 3       Afghanistan  2020-01-07        0.0            0         0.0
# 4       Afghanistan  2020-01-08        0.0            0         0.0
# ...             ...         ...        ...          ...         ...
# 558253     Zimbabwe  2026-02-18        0.0       266436         0.0
# 558254     Zimbabwe  2026-02-19        0.0       266436         0.0
# 558255     Zimbabwe  2026-02-20        0.0       266436         0.0
# 558256     Zimbabwe  2026-02-21        0.0       266436         0.0
# 558257     Zimbabwe  2026-02-22        0.0       266436         0.0
#
#         total_deaths  weekly_cases  weekly_deaths  weekly_pct_growth_cases  \
# 0                  0           NaN            NaN                      NaN
# 1                  0           NaN            NaN                      NaN
# 2                  0           NaN            NaN                      NaN
# 3                  0           NaN            NaN                      NaN
# 4                  0           NaN            NaN                      NaN
# ...              ...           ...            ...                      ...
# 558253          5740           0.0            0.0                      NaN
# 558254          5740           0.0            0.0                      NaN
# 558255          5740           0.0            0.0                      NaN
# 558256          5740           0.0            0.0                      NaN
# 558257          5740           0.0            0.0                      NaN
#
#         weekly_pct_growth_deaths  ...  cfr_100_cases  cfr_short_term  \
# 0                            NaN  ...            NaN             NaN
# 1                            NaN  ...            NaN             NaN
# 2                            NaN  ...            NaN             NaN
# 3                            NaN  ...            NaN             NaN
# 4                            NaN  ...            NaN             NaN
# ...                          ...  ...            ...             ...
# 558253                       NaN  ...       2.154364             NaN
# 558254                       NaN  ...       2.154364             NaN
# 558255                       NaN  ...       2.154364             NaN
# 558256                       NaN  ...       2.154364             NaN
# 558257                       NaN  ...       2.154364             NaN
#
#         days_since_100_total_cases  days_since_5_total_deaths  \
# 0                            -86.0                      -91.0
# 1                            -85.0                      -90.0
# 2                            -84.0                      -89.0
# 3                            -83.0                      -88.0
# 4                            -82.0                      -87.0
# ...                            ...                        ...
# 558253                      2094.0                     2176.0
# 558254                      2095.0                     2177.0
# 558255                      2096.0                     2178.0
# 558256                      2097.0                     2179.0
# 558257                      2098.0                     2180.0
#
#         days_since_1_total_cases_per_million  \
# 0                                      -81.0
# 1                                      -80.0
# 2                                      -79.0
# 3                                      -78.0
# 4                                      -77.0
# ...                                      ...
# 558253                                2136.0
# 558254                                2137.0
# 558255                                2138.0
# 558256                                2139.0
# 558257                                2140.0
#
#         days_since_0_1_total_deaths_per_million  \
# 0                                         -91.0
# 1                                         -90.0
# 2                                         -89.0
# 3                                         -88.0
# 4                                         -87.0
# ...                                         ...
# 558253                                   2176.0
# 558254                                   2177.0
# 558255                                   2178.0
# 558256                                   2179.0
# 558257                                   2180.0
#
#         days_since_100_total_cases_and_5m_pop  total_deaths_last12m  \
# 0                                       -86.0                   NaN
# 1                                       -85.0                   NaN
# 2                                       -84.0                   NaN
# 3                                       -83.0                   NaN
# 4                                       -82.0                   NaN
# ...                                       ...                   ...
# 558253                                 2094.0                   0.0
# 558254                                 2095.0                   0.0
# 558255                                 2096.0                   0.0
# 558256                                 2097.0                   0.0
# 558257                                 2098.0                   0.0
#
#         total_deaths_per_100k_last12m  total_deaths_per_million_last12m
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 558253                            0.0                               0.0
# 558254                            0.0                               0.0
# 558255                            0.0                               0.0
# 558256                            0.0                               0.0
# 558257                            0.0                               0.0
#
# [558258 rows x 40 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 4 (actual part)
#
# Βρείτε από το ourworldindata.org ένα dataset που σας ενδιαφέρει και ανοίξτε το σαν dataframe.

# %%
covid_vaccinations = df = pd.read_csv("https://catalog.ourworldindata.org/garden/covid/latest/yougov/yougov_composite.csv")
covid_vaccinations
# Out:
#            country        date  people_vaccinated_per_hundred  \
# 0        Australia  2021-03-15                           0.71
# 1        Australia  2021-04-15                           4.82
# 2        Australia  2021-05-15                          10.70
# 3        Australia  2021-06-15                          20.00
# 4        Australia  2021-07-15                          27.57
# ..             ...         ...                            ...
# 167  United States  2021-06-15                          53.77
# 168  United States  2021-07-15                          56.16
# 169  United States  2021-08-15                          60.05
# 170  United States  2021-09-15                          63.49
# 171  United States  2021-10-15                          65.64
#
#      uncertain_covid_vaccinate_this_week_pct_pop  \
# 0                                          19.80
# 1                                          20.13
# 2                                          20.71
# 3                                          18.91
# 4                                          15.70
# ..                                           ...
# 167                                         7.30
# 168                                         8.35
# 169                                         8.99
# 170                                         6.21
# 171                                         5.17
#
#      unwillingness_covid_vaccinate_this_week_pct_pop  \
# 0                                              27.72
# 1                                              31.32
# 2                                              31.14
# 3                                              28.45
# 4                                              25.69
# ..                                               ...
# 167                                            31.26
# 168                                            28.17
# 169                                            23.75
# 170                                            23.68
# 171                                            25.42
#
#      willingness_covid_vaccinate_this_week_pct_pop
# 0                                            51.77
# 1                                            43.73
# 2                                            37.45
# 3                                            32.64
# 4                                            31.04
# ..                                             ...
# 167                                           7.67
# 168                                           7.32
# 169                                           7.21
# 170                                           6.62
# 171                                           3.77
#
# [172 rows x 6 columns]
